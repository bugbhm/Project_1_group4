# %%
#import all necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import gmaps
from census import Census
from data import (census_key, gkey)
from us import states
import geopy

# Census API Key
#c = Census(census_key, year=2018)

# %%
# Import the original data. Use dtype="object" to match other
med_household_income = pd.read_csv("Affordability_Income_2018Q4.csv", dtype="object", encoding="latin-1")

# Visualize
med_household_income.head()
# Out:
#   RegionID                          RegionName SizeRank   1979-03   1979-06  \
# 0   102001                       United States        0  16346.86  16675.92
# 1   394913                        New York, NY        1  17536.34  17888.75
# 2   753899  Los Angeles-Long Beach-Anaheim, CA        2  17913.83  18285.02
# 3   394463                         Chicago, IL        3  20056.35  20460.12
# 4   394514               Dallas-Fort Worth, TX        4  18147.33  18458.77
#
#     1979-09   1979-12   1980-03   1980-06   1980-09  ...   2016-09   2016-12  \
# 0  17015.62  17325.61  17700.06  18003.37  18309.93  ...  57766.34   58360.4
# 1  18255.17  18614.93  19075.72  19493.98  19894.97  ...  72364.87  72812.68
# 2  18746.27  19213.79  19782.36  20306.08  20737.44  ...  66466.82   67400.6
# 3  20910.06  21267.37   21678.2   21848.9  21984.03  ...  65979.46  66579.67
# 4  18899.16   19454.8  20069.21  20608.07  21021.31  ...  64606.25  65180.46
#
# ...

# %%
#take the data every 10 years instead of every 3 months to see more drastic changes at first
med_income_decade = med_household_income.loc[:, ["RegionID", "RegionName", "1980-03", "1990-03", "2000-03", "2010-03", "2018-03"]]
med_income_decade = med_income_decade.rename(columns={"1980-03": "1980",
                                                      "1990-03": "1990",
                                                      "2000-03": "2000",
                                                      "2010-03": "2010",
                                                     "2018-03": "2018",})

#drop the first row because it is the US not a city or region
med_income_decade = med_income_decade.drop(med_income_decade.index[[0]])
med_income_decade
# Out:
#     RegionID                          RegionName      1980      1990  \
# 1     394913                        New York, NY  19075.72  38933.73
# 2     753899  Los Angeles-Long Beach-Anaheim, CA  19782.36   37703.9
# 3     394463                         Chicago, IL   21678.2  36168.78
# 4     394514               Dallas-Fort Worth, TX  20069.21  33010.16
# 5     394974                    Philadelphia, PA   19067.8  36228.52
# ..       ...                                 ...       ...       ...
# 929   394767                          Lamesa, TX       NaN       NaN
# 930   753874                           Craig, CO       NaN       NaN
# 931   394968                           Pecos, TX       NaN       NaN
# 932   395188                          Vernon, TX       NaN       NaN
# 933   394743                       Ketchikan, AK       NaN       NaN
#
#          2000      2010         2018
# 1    51907.73  65121.91  77408.08281
# 2    46814.62  57366.27  71844.90526
# ...

# %%
cities_info_df = pd.read_csv("us-zip-code-latitude-and-longitude.csv", sep=";", dtype="object", encoding="utf-8")
cities_info_df = cities_info_df.loc[:, ["Zip", "City", "State", "Latitude", "Longitude"]]
# Visualize
cities_info_df
# Out:
#          Zip          City State   Latitude   Longitude Timezone  \
# 0      71937          Cove    AR  34.398483   -94.39398       -6
# 1      72044      Edgemont    AR  35.624351   -92.16056       -6
# 2      56171      Sherburn    MN  43.660847   -94.74357       -6
# 3      49430        Lamont    MI  43.010337   -85.89754       -5
# 4      52585      Richland    IA  41.194129   -91.98027       -6
# ...      ...           ...   ...        ...         ...      ...
# 43186  66860       Madison    KS  38.126728   -96.16635       -6
# 43187  59602        Helena    MT  46.696501  -111.96895       -7
# 43188  16063    Zelienople    PA  40.783001   -80.13343       -5
# 43189  18913  Carversville    PA  40.376499   -75.04129       -5
# 43190  25901      Oak Hill    WV  37.982775   -81.14533       -5
#
#       Daylight savings time flag             geopoint,
# 0                              1   34.398483,-94.39398
# 1                              1   35.624351,-92.16056
# ...

# %%
#Clean up data and eliminate rows

# %%
#importing census data about age groups
c = Census(census_key, year=2011)

census_data = c.acs5.get(("B01002_001E", "B01002_002E", "B01002_003E"), {
                         "for": "zip code tabulation area:*"})

# Convert to DataFrame
census_age_pd = pd.DataFrame(census_data)

# Column Reordering
census_age_pd = census_pd.rename(columns={"B01002_001E": "Median Age",
                                      "B01002_002E": "Median Male Age",
                                      "B01002_003E": "Median Female Age",
                                      "zip code tabulation area": "Zipcode"})

census_age_pd.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\census\core.py in query(self, fields, geo, year, **kwargs)
#     180             try:
# --> 181                 data = resp.json()
#     182             except ValueError as ex:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# ...

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = cities_info_df[["lat", "lng"]].astype(float)

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
population_density = cities_info_df["density"].astype(float)

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer_pop_density = gmaps.heatmap_layer(locations, weights=population_density, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer_pop_density.dissipating = False
heat_layer_pop_density.max_intensity = 100
heat_layer_pop_density.point_radius = .01

fig.add_layer(heat_layer_1979)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
